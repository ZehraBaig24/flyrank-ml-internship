# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZehraBaig24/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane

#I chose **Refresh / Content Opportunity Scoring** because I want to identify which web pages should be reviewed first for improvement. Instead of checking every page manually, I want to use the available search performance data to find pages that are most likely to benefit from updates. This lane is useful because it helps content teams prioritize their work using evidence from the data rather than guessing.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
### The Question

#**Research Question:**

#Can we identify which web pages should be reviewed first based on their search performance?

#**Decision**

#The decision is choosing which pages should be reviewed before others.

#**Action**

#The content or SEO team can update, improve, or monitor the selected pages.

#**Cost of a Wrong Recommendation**

#If the recommendation is wrong, the team may spend time improving pages that do not need changes, while important pages that actually need attention could be ignored.

#**Why Machine Learning?**

#A website may contain thousands of pages. Reviewing each page manually is slow and difficult. Machine learning can identify patterns in the data and help prioritize the pages that deserve attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("./data/raw/content_refresh_anonymized.csv")

print(df.shape)

print(df["impressions_90d"].describe())

print(df["clicks_90d"].describe())

print(df["ctr"].describe())

## Quick Look at the Data

#The starter dataset contains **30,000 web pages** and **44 features**, which provides enough data for analysis.

#The average number of impressions over the last 90 days is **5,200.37**, while the average number of clicks is **16.10**. The average CTR is **0.51%**.

#These numbers show that page performance varies across the dataset. This makes it useful for identifying pages that may need content updates or further review, which supports my choice of the Refresh / Content Opportunity Scoring lane.
# Out:
# (30000, 44)
# count     30000.000000
# mean       5200.366300
# std       16838.019547
# min           1.000000
# 25%          81.000000
# 50%         731.000000
# 75%        3615.250000
# max      517715.000000
# Name: impressions_90d, dtype: float64
# count    30000.000000
# mean        16.097333
# std         75.076958
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          7.000000
# max       4178.000000
# Name: clicks_90d, dtype: float64
# count    30000.000000
# mean         0.510733
# std          3.279162
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.290000
# max        100.000000
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
## Careful Words

#This project uses search performance data to identify web pages that may need review. The results are meant to support decision-making and help prioritize which pages to improve first.

#The model can identify patterns in the available data, but it cannot prove that updating a page will improve its performance. It also cannot predict Google's ranking algorithm or guarantee future results. Any recommendations should be reviewed by a human before taking action.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
